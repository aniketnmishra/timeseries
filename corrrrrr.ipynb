# %%
import pandas as pd
import seaborn as sns
import numpy as np
import tensorflow as tf
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from getxy import getxy
# %matplotlib inline
import functions

data = pd.read_csv('MasterOnlyPriceNAremoved.csv')

print(data.columns)


c_matrix=data.corr()

sns.heatmap(c_matrix,cmap="Blues")
# Out:
# Index(['Date', 'jci-price', 'sensex-price', 'psei-price', 'ibov-price',
#        'inr-price', 'php-price', 'brl-price', 'idr-price', 'gold-price',
#        'crude-price'],
#       dtype='object')

# %%
y = data['inr-price']

# %%
auto_y = np.correlate(y,data['inr-price'],mode="same")

# %%
auto_y.shape
# Out:
# (2973,)

# %%
cols = data.columns

# %%
cols = cols.drop("Date")

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
for col in cols:
    print(col)
    plot_acf(data[col],title = col)
# Out:
# jci-price
# sensex-price
# psei-price
# ibov-price
# inr-price
# php-price
# brl-price
# idr-price
# gold-price
# crude-price

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
for col in cols:
    print(col)
    plot_pacf(data[col],title = col)
#plot_pacf(data['inr-price'])
# Out:
# jci-price
# sensex-price
# psei-price
# ibov-price
# inr-price
# php-price
# brl-price
# idr-price
# gold-price
# crude-price

# %%
x = data['sensex-price']
n = len(x)
variance = x.var()
x = x-x.mean()
r = np.correlate(x, x, mode = 'full')[-n:]

# %%
plt.plot(r/r.max())

# %%
plt.plot(x)

# %%
r/r.max()
# Out:
# array([ 1.        ,  0.99806333,  0.99607711, ..., -0.00402774,
#        -0.0027053 , -0.00135736])

# %%
import statsmodels

# %%
rr = statsmodels.tsa.stattools.acf(data['sensex-price'])

# %%
rr.shape
# Out:
# (41,)

# %%
rr
# Out:
# array([1.        , 0.99806333, 0.99607711, 0.99414712, 0.99221427,
#        0.99035608, 0.98847216, 0.98656325, 0.98466281, 0.9827726 ,
#        0.98086215, 0.97892706, 0.97698414, 0.97506968, 0.97319054,
#        0.9713424 , 0.96952563, 0.96776566, 0.96603113, 0.96427458,
#        0.9625224 , 0.96079427, 0.95912368, 0.95746756, 0.95579715,
#        0.95407   , 0.95232991, 0.95058563, 0.94882526, 0.94705935,
#        0.94526294, 0.94342522, 0.94156767, 0.93978277, 0.93802491,
#        0.93628384, 0.93463905, 0.93302813, 0.93139498, 0.92975752,
#        0.92812744])

# %%
plt.plot(rr)

# %%
rr = statsmodels.tsa.stattools.pacf(data['jci-price'], nlags=10, method='ywunbiased', alpha=None)

# %%
plt.plot(rr)

# %%
rr
# Out:
# array([ 1.        ,  0.99902272, -0.01387777,  0.01905068,  0.0151262 ,
#         0.03548441, -0.00275393, -0.0083885 , -0.00869314,  0.00250124,
#         0.0043755 ])

# %%
test = statsmodels.stats.diagnostic.breaks_cusumolsresid(olsresidual, ddof=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-7aac671bdecb> in <module>
# ----> 1 test = statsmodels.stats.diagnostic.breaks_cusumolsresid(olsresidual, ddof=0)
#
# AttributeError: module 'statsmodels.stats' has no attribute 'diagnostic'
